# %% [markdown]
# # Higher Highs
#
# ### SLV - 2019-10-17 to 2020-12-23
#
# ### looking at  the price differances between trend changes
# ## How
# - i grouped data by only times when the trend changed
# > `last_high_was_higher and last_low_was_higher == True`
#
# ![image.png](attachment:image.png)
#
# ## suprisingly enough the data show the reverse of what i would have expected ... from the crude
#
#
# ### a more usefull variation would be to only take the difference ffrom the first higher low, of trend change!

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # Buying first Trend Change
# ### > in these examples price hit 10% up before it hit 5% down 71% of the time.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Capital gained 48% return in less than a year
# - this is biased b/c the whole chart is going up
# - so i must test the inverse
# ![image.png](attachment:image.png)

# %% [markdown]
# # Win PNL Long
# ![image.png](attachment:image.png)

# %% [markdown]
# # i feel like an actual researcher now.

# %% [markdown]
# # Since 2006
# ![image.png](attachment:image.png)
#
# - it seems to outpreform the security but over enough time it finds equal librium with the sec
# >its possible with a striter criteria or a limit order somewhere it will preform exponetially better

# %% [markdown]
# # up_target: 10
#
# # stop_target: 5
#
# # ![image.png](attachment:image.png)

# %% [markdown]
# # up_Targ : 5
# # dn_targ : 2
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # POTENTIAL!!
# > THIS WOULD DO SO MUCH BETTER IF THERE WAS SOME KIND OF VALIDATION OR TRAILING STOP SELL!!!!!
#
# ## up targ : 20
# ## dn targ : 5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # This looks Very promising!!
# ### higher highs inside weekly trends...
# ![Screenshot%20from%202020-12-25%2006-32-27.png](attachment:Screenshot%20from%202020-12-25%2006-32-27.png)

# %% [markdown]
# # and also very promising on the short side as well!!!!
# ![image.png](attachment:image.png)

# %% [markdown]
# # `small - sample time- frame`
# # Short trend change buy `vs` trend change buy WITH weekly condition
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # with weekly condition
#
# ![image.png](attachment:image.png)
#
#
#
# ## even tho the verion_without_condition had higher gains, the condition avoided that huge pothole!!!!
# ## and win pct is higher on the condition
# # im going to call this a win!!!

# %% [markdown]
# # SUPRISE:
# - not really the non conditin out preformed the condition again
# - but condition got a higher win_pct
# ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # Conclusions
# ### > POTENTIAL theres alot of upside on the 20% targ vs 5%, so
# #### a smaller time frame system should be nimble enough to CREAM this shit. within the patterns
# # REVOLATION - I did my short function wrong!!!
# - so all my short candle stick data is wrong
# > WHICH MAY HAVE BEEN A DISCOVERY .
# - b/c an accedental blessing belt line has preformed VERY well
#
# ### never the less i need to redo all my short research

# %% [markdown]
# # TODO
# - back test on first sign of trend change
# > - do an inverse one as a control...
# > - just make short function already
# - only use values from the first higher low
# - combine the weekly trend with the local trend...
# - do the same on the monthly
# - you know... fix the plotting function in backtest!
# - ADD TRAILING STOP TO ONE_STOP
# > if len(trailing) == True:
# >     - then sell it triggered on touch?
# >     - or close?
#
# # other reasearch projects
# - got to redo all of super trends now that backtester works properly
# - which options contracts are the best to buy in what situations?
# > are there common denominators in `the GREEKS`
# >
#
# - band smack
# - THE VALIDATION FUNCTION
# > SO JUST MAKE IT A TRAILING STOP FUNCTION B/C YOU CAN PUT VALIDATION IN THAT AS WELL AS ANYTHING ELSE ( far more versitrile
# > ALL YOU HAVE TO DO
# > - change one line of code MAKE: df[stop_tart][i-1] into df['trailing_sop][i] BAM

# %% [markdown]
# # Furthur Questions
# - do candle stick patterns preform better in the context of a trend based on these criteria
# - do piviot points out preform these.
# - how often is a vma a good buy when you are in a layered trend...
# - how often are weekly riz extreams profitable
# ![Screenshot%20from%202020-11-30%2002-05-08.png](attachment:Screenshot%20from%202020-11-30%2002-05-08.png)
